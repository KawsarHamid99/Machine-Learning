# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1=pd.read_csv("archive/Bitcoin_tweets.csv")
df1.head()
# Out:
# F:\game\anaconda\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (5,6,7,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                                   user_name    user_location  \
# 0                             DeSota Wilson      Atlanta, GA
# 1                                  CryptoND              NaN
# 2                                 Tdlmatias  London, England
# 3                      Crypto is the future              NaN
# 4  Alex Kirchmaier 🇦🇹🇸🇪 #FactsSuperspreader           Europa
#
#                                     user_description         user_created  \
# 0  Biz Consultant, real estate, fintech, startups...  2009-04-26 20:05:09
# 1  😎 BITCOINLIVE is a Dutch platform aimed at inf...  2019-10-17 20:12:10
# 2  IM Academy : The best #forex, #SelfEducation, ...  2014-11-10 10:50:37
# ...

# %%
df2=pd.read_csv("archive/Bitcoin.csv")
df2.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  28-05-2021  38507.083075  38856.967885  34779.039427  35697.606390
# 1  27-05-2021  39316.889678  40379.617672  37247.903676  38436.968535
# 2  26-05-2021  38392.623656  40782.078183  37905.834854  39294.197382
# 3  25-05-2021  38795.780250  39776.349798  36581.428916  38402.223851
# 4  24-05-2021  34700.363568  39835.139830  34551.080550  38705.978637
#
#          Volume    Market Cap
# 0  5.520019e+10  6.682839e+11
# 1  4.321097e+10  7.195381e+11
# 2  5.134674e+10  7.355564e+11
# 3  5.621192e+10  7.188294e+11
# 4  6.735958e+10  7.243321e+11

# %%
df2["Date"].dtype,df2["Open"].dtype,df2["High"].dtype,df2["Close"].dtype,df2["Low"].dtype,df2["Volume"].dtype
# Out:
# (dtype('O'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'),
#  dtype('float64'))

# %%
type(df2["Date"])
# Out:
# pandas.core.series.Series

# %%
df2.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count   2953.000000   2953.000000   2953.000000   2953.000000  2.953000e+03
# mean    6315.811956   6496.437203   6118.113348   6327.536586  1.054393e+10
# std    10853.865920  11194.114680  10456.360555  10866.056805  1.872924e+10
# min       68.504997     74.561096     65.526001     68.431000  0.000000e+00
# 25%      425.631989    433.743011    420.510010    425.190002  2.971700e+07
# 50%     1756.520020   1831.420044   1708.540039   1787.130005  7.680150e+08
# 75%     8290.759766   8470.987890   8110.770020   8293.867741  1.522041e+10
# max    63523.754869  64863.098908  62208.964366  63503.457930  3.509679e+11
#
#          Market Cap
# count  2.953000e+03
# mean   1.136229e+11
# std    2.026335e+11
# min    7.784112e+08
# 25%    6.262845e+09
# 50%    2.917097e+10
# 75%    1.468189e+11
# max    1.186364e+12

# %%
df2.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  28-05-2021  38507.083075  38856.967885  34779.039427  35697.606390
# 1  27-05-2021  39316.889678  40379.617672  37247.903676  38436.968535
# 2  26-05-2021  38392.623656  40782.078183  37905.834854  39294.197382
# 3  25-05-2021  38795.780250  39776.349798  36581.428916  38402.223851
# 4  24-05-2021  34700.363568  39835.139830  34551.080550  38705.978637
#
#          Volume    Market Cap
# 0  5.520019e+10  6.682839e+11
# 1  4.321097e+10  7.195381e+11
# 2  5.134674e+10  7.355564e+11
# 3  5.621192e+10  7.188294e+11
# 4  6.735958e+10  7.243321e+11

# %%
df2["average"]=(df2["Open"]+df2["High"]+df2["Low"]+df2["Close"])/4

# %%
df2.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  28-05-2021  38507.083075  38856.967885  34779.039427  35697.606390
# 1  27-05-2021  39316.889678  40379.617672  37247.903676  38436.968535
# 2  26-05-2021  38392.623656  40782.078183  37905.834854  39294.197382
# 3  25-05-2021  38795.780250  39776.349798  36581.428916  38402.223851
# 4  24-05-2021  34700.363568  39835.139830  34551.080550  38705.978637
#
#          Volume    Market Cap       average
# 0  5.520019e+10  6.682839e+11  36960.174194
# 1  4.321097e+10  7.195381e+11  38845.344890
# 2  5.134674e+10  7.355564e+11  39093.683519
# 3  5.621192e+10  7.188294e+11  38388.945704
# 4  6.735958e+10  7.243321e+11  36948.140646

# %%
fig, ax = plt.subplots(figsize=(15, 9))
x = np.arange(len(df2["Date"]))
ax.plot(x, df2["average"], color='blue', linewidth=1, linestyle='-')
l, = ax.plot(x, df2["Low"], color='orange', linewidth=1)
l.set_linestyle('-');

# %%
fig, ax = plt.subplots(figsize=(15, 9))
x = np.arange(len(df2["Date"]))
ax.plot(x, df2["average"], color='blue', linewidth=1, linestyle='-')
l, = ax.plot(x, df2["High"], color='orange', linewidth=1)
l.set_linestyle('-');

# %%
fig, ax = plt.subplots(figsize=(15, 9))
x = np.arange(len(df2["Date"]))
ax.plot(x, df2["average"], color='blue', linewidth=1, linestyle='-')
l, = ax.plot(x, df2["Low"], color='orange', linewidth=1)
l.set_linestyle('-');

# %%
fig, ax = plt.subplots(figsize=(150, 9))
x = np.arange(len(df2["Date"]))
ax.plot(x, df2["average"], color='blue', linewidth=1, linestyle='-')
l, = ax.plot(x, df2["High"], color='orange', linewidth=1)
l.set_linestyle('-');

# %%
df2.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# average       0
# dtype: int64

# %%
from fbprophet import
